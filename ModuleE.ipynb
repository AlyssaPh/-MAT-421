# %% [markdown]
# <a href="https://colab.research.google.com/github/AlyssaPh/-MAT-421/blob/main/ModuleE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **CALCULUS AND OPTIMIZATION**

# %% [markdown]
# **3.2.1 CONTINUNITY AND DIFFERENTIATION**

# %%
import numpy as np
import sympy
import matplotlib.pyplot as plt
x=np.linspace(0,5,500)
y=np.sin(2*x)+np.sin(4*x)
plt.plot(x,y)

# %%
#finding the limit of the function
x = sympy.Symbol('x')
sympy.limit(sympy.sin(2*x)+sympy.sin(4*x), x, 0)
# Out:
# 0

# %% [markdown]
# **3.2.2 DERIVATIVES**

# %%
#The derivative of my equation
x=np.linspace(0,5,500)
h=0.01
diff_eq=np.diff(y)/h
x_diff = x[:-1:]
real_eq = 2*np.cos(2*x_diff) + 4*np.cos(4*x_diff)
plt.plot(x_diff, diff_eq, '--', label = 'computer solved equation')
plt.plot(x_diff, real_eq,label = 'Exact Solution')
plt.legend()
plt.show()

# %% [markdown]
# **3.2.3 TAYLOR'S THEOREM**

# %%
from sympy import *
#Finding the Talor series for my equation
x = sympy.Symbol('x')
g= x
eq=sin(2*g) + sin(4*x)
taylorExpand = eq.series(x, 0, 3).removeO()
display(taylorExpand)

p1 = plot(eq, show=False)
p2 = plot(taylorExpand, show=False)
p1.append(p2[0])
print('Taylor expansion shows ok behavior near the 0')
p1.show()
# Out:
# 6*x
# Taylor expansion shows ok behavior near the 0

# %% [markdown]
# **3.3.1 OPTIMIZATION**

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the function and its derivative
def f(x):
    return x**2

def df(x):
    return 2*x

# Gradient Descent Algorithm
def gradient_descent(starting_point, learning_rate, num_iterations):
    x = starting_point
    history = [x]  # To store the history of x values
    for _ in range(num_iterations):
        gradient = df(x)
        x = x - learning_rate * gradient
        history.append(x)
    return x, history

# Parameters
starting_point = 10.0
learning_rate = 0.1
num_iterations = 50

# Run Gradient Descent
optimal_x, history = gradient_descent(starting_point, learning_rate, num_iterations)

# Plot the results
x_values = np.linspace(-11, 11, 400)
y_values = f(x_values)

plt.plot(x_values, y_values, label="f(x) = x^2")
plt.scatter(history, [f(x) for x in history], color='red', label="Gradient Descent Steps")
plt.xlabel("x")
plt.ylabel("f(x)")
plt.title("Gradient Descent Optimization")
plt.legend()
plt.grid()
plt.show()

print(f"Optimal x: {optimal_x}")
# Out:
# Optimal x: 0.00014272476927059603

# %% [markdown]
# **3.3.2 CONVEXITY**

# %%
def is_convex(f, df, ddf, domain):
    # Check if the second derivative is non-negative over the domain
    x_values = np.linspace(domain[0], domain[1], 1000)
    for x in x_values:
        if ddf(x) < 0:
            return False
    return True

# Define the second derivative
def ddf(x):
    return 2

# Check convexity
domain = (-10, 10)
convex = is_convex(f, df, ddf, domain)
print(f"Is the function convex? {convex}")
# Out:
# Is the function convex? True
