# %% [markdown]
# <a href="https://colab.research.google.com/github/AlyssaPh/-MAT-421/blob/main/ModuleG(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **21.4 Simpson’s Rule**

# %%
import numpy as np

a = 10
b = np.pi
n = 20
h = (b - a) / (n - 1)
x = np.linspace(a, b, n)
f = np.sin(x)

I_simp = (h/3) * (f[0] + 2*sum(f[:n-2:2]) \
            + 4*sum(f[1:n-1:2]) + f[n-1])
err_simp = 2 - I_simp

print(I_simp)
print(err_simp)
# Out:
# 0.1849135000872394
# 1.8150864999127605

# %% [markdown]
# **21.5 Computing Integrals in Python**

# %%
import numpy as np
from scipy.integrate import trapz

a = 10
b = np.pi
n = 20
h = (b - a) / (n - 1)
x = np.linspace(a, b, n)
f = np.sin(x)

I_trapz = trapz(f,x)
I_trap = (h/2)*(f[0] + 2 * sum(f[1:n-1]) + f[n-1])

print(I_trapz)
print(I_trap)
# Out:
# 0.1591772698005526
# 0.15917726980055277
# <ipython-input-2-db226c55b476>:11: DeprecationWarning: 'scipy.integrate.trapz' is deprecated in favour of 'scipy.integrate.trapezoid' and will be removed in SciPy 1.14.0
#   I_trapz = trapz(f,x)

# %%
from scipy.integrate import cumtrapz
import matplotlib.pyplot as plt

x = np.arange(0, np.pi, 0.05)
F_exact = -np.sin(x)
F_approx = cumtrapz(np.cos(x), x)

plt.figure(figsize = (20,10))
plt.plot(x, F_exact)
plt.plot(x[1::], F_approx)
plt.grid()
plt.tight_layout()
plt.title('$F(x) = \int_0^{x} cos(y) dy$')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend(['Exact with Offset', 'Approx'])
plt.show()
# Out:
# <ipython-input-9-6c9f804372c3>:6: DeprecationWarning: 'scipy.integrate.cumtrapz' is deprecated in favour of 'scipy.integrate.cumulative_trapezoid' and will be removed in SciPy 1.14.0
#   F_approx = cumtrapz(np.cos(x), x)

# %%
from scipy.integrate import quad

I_quad, est_err_quad = \
          quad(np.cos, 0, np.pi)
print(I_quad)
err_quad = 2 - I_quad
print(est_err_quad, err_quad)
# Out:
# 4.9225526349740854e-17
# 2.2102239425853306e-14 2.0
